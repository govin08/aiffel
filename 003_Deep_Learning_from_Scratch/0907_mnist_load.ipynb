# %% [markdown]
# **<밑바닥부터 시작하는 딥러닝>의 3장에서의 mnist dataset 불러오기 방법입니다.**
#
# 저와 같은 어려움을 겪으실 분이 계실 수도 있을 것 같아서 씁니다.
#
# 0. 아이펠 클라우드 상에서 jupyter notebook으로 작업하고 계시다는 가정 하에 씁니다.
#
# 1. [다음](https://drive.google.com/file/d/1IQXvFigDTVKlcZAP2oTgTMOXqdhFOsZ_/view) 링크에서 압축파일을 다운받습니다.
#
# 2. 압축을 풉니다.
#
# 3. 압축을 풀면, 'dataset'이라는 폴더가 생성되고, 그 안에 __init__.py 이라든지, mnist.py 라든지, t10k-images-idx3-ubyte.gz 라든지, t10k-labels-idx1-ubyte.gz 라든지, train-images-idx3-ubyte.gz 라든지 train-labels-idx1-ubyte.gz 라든지 하는 파일들이 있게 됩니다.
#
# 4. jupyter notebook으로 작업하고 계신 파일이 있는 곳에 폴더를 만듭니다. 아래 캡쳐와 같이요.
#
# ![image.png](attachment:image.png)
#
#
#
# 5. 폴더의 이름을 'dataset'으로 바꿉니다.
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# 6. 해당 폴더 'dataset'에 들어가 upload 버튼을 누르고, 아까 다운받았던 파일들 (__init__.py, mnist.py, t10k-images-idx3-ubyte.gz, t10k-labels-idx1-ubyte.gz, train-images-idx3-ubyte.gz, train-labels-idx1-ubyte.gz, 등등)을 모조리 업로드합니다.
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# 7. 그러면, 해당 셀이 잘 동작하게 됩니다.
#
# ![image-6.png](attachment:image-6.png)
