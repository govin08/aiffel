# %% [markdown]
# # 3. 신경망

# %% [markdown]
# 이 장에서는 신경망의 순전파에 대해서 다룬다.
# 다음과 같은 것들이 언급된다.
#  - 신경망
#  - 활성화함수 : sigmoid ,ReLU, softmax
#  - numpy로 신경망 구성하여 순전파 구현하기
#  - MNIST에 적용

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 3.1. 퍼셉트론에서 신경망으로

# %% [markdown]
# ### 3.1.1. 신경망의 예

# %% [markdown]
# ![image.png](attachment:image.png)
#  - 입력층
#  - 출력층
#  - 은닉층

# %% [markdown]
# ### 3.1.2. 퍼셉트론 복습

# %% [markdown]
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-4.png](attachment:image-4.png)
#
#  - weight
#  - bias

# %% [markdown]
# ### 3.1.3. 활성화 함수의 등장

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
#  - 활성화 함수 (activation function)
#  - 뉴런(노드)

# %% [markdown]
# ## 3.2. 활성화 함수

# %% [markdown]
# ### 3.2.1. 시그모이드 함수

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3.2.2. 계단 함수 구현하기

# %%
# step function, python
def step_function(x):
    if x > 0:
        return 1
    else:
        return 0

# %% [markdown]
# `x`에 `int`, `float`가 들어갈 수 있다.
#  `np.array`를 넣으면 오류가 난다.

# %%
print(step_function(2))
print(step_function(2.0))
# print(step_function(np.array([2,3]))) # error
# Out:
# 1
# 1

# %%
# step function, python
def step_function(x):
    y = x > 0
    return y.astype(np.int64)

# %% [markdown]
# 한용님의 조언 `astype(np.int) -> astype(np.int64) or astype(int)`을 따랐다.

# %% [markdown]
# 반대로, `int`, `float`가 들어갈 수 없다.
# `np.array`는 잘 작동한다.
# if 문을 넣으면 둘 모두 작용될 수 있게 할 수 있겠지만, 굳이 그렇게까지 하고 있지는 않다. (일종의 method overloading)

# %%
# print(step_function(2))
# print(step_function(2.0))
print(step_function(np.array([2,3]))) # error
# Out:
# [1 1]

# %% [markdown]
# ### 3.2.3. 계단함수의 그래프

# %%
x = np.arange(-5,5,0.1)
y = step_function(x)
plt.plot(x,y)
plt.ylim(-0.1,1.1)
# Out:
# (-0.1, 1.1)

# %% [markdown]
# 당연히, 이것은 엄밀한 의미의 step function graph가 아니다.
# 유한개의 점들만 찍어서 이었다는 점은 차치하더라도, 저 중간의 올라가는 모양이 없어야 한다.

# %% [markdown]
# ### 3.2.4. 시그모이드 함수 구현하기

# %% [markdown]
#  - NumPy의 broadcasting

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
for x in np.arange(-3,3,0.1):
    print("x : {0:.1f}, sigmoid : {1:5.4f}".format(x,sigmoid(x)))
#    print("x = {0} : sigmoid = {1}")
#    print(sigmoid(x))
# Out:
# x : -3.0, sigmoid : 0.0474
# x : -2.9, sigmoid : 0.0522
# x : -2.8, sigmoid : 0.0573
# x : -2.7, sigmoid : 0.0630
# x : -2.6, sigmoid : 0.0691
# x : -2.5, sigmoid : 0.0759
# x : -2.4, sigmoid : 0.0832
# x : -2.3, sigmoid : 0.0911
# x : -2.2, sigmoid : 0.0998
# x : -2.1, sigmoid : 0.1091
# x : -2.0, sigmoid : 0.1192
# x : -1.9, sigmoid : 0.1301
# x : -1.8, sigmoid : 0.1419
# x : -1.7, sigmoid : 0.1545
# x : -1.6, sigmoid : 0.1680
# x : -1.5, sigmoid : 0.1824
# x : -1.4, sigmoid : 0.1978
# x : -1.3, sigmoid : 0.2142
# x : -1.2, sigmoid : 0.2315
# x : -1.1, sigmoid : 0.2497
# x : -1.0, sigmoid : 0.2689
# x : -0.9, sigmoid : 0.2891
# x : -0.8, sigmoid : 0.3100
# x : -0.7, sigmoid : 0.3318
# x : -0.6, sigmoid : 0.3543
# x : -0.5, sigmoid : 0.3775
# x : -0.4, sigmoid : 0.4013
# x : -0.3, sigmoid : 0.4256
# x : -0.2, sigmoid : 0.4502
# x : -0.1, sigmoid : 0.4750
# x : 0.0, sigmoid : 0.5000
# x : 0.1, sigmoid : 0.5250
# x : 0.2, sigmoid : 0.5498
# x : 0.3, sigmoid : 0.5744
# x : 0.4, sigmoid : 0.5987
# x : 0.5, sigmoid : 0.6225
# x : 0.6, sigmoid : 0.6457
# x : 0.7, sigmoid : 0.6682
# x : 0.8, sigmoid : 0.6900
# x : 0.9, sigmoid : 0.7109
# x : 1.0, sigmoid : 0.7311
# x : 1.1, sigmoid : 0.7503
# x : 1.2, sigmoid : 0.7685
# x : 1.3, sigmoid : 0.7858
# x : 1.4, sigmoid : 0.8022
# x : 1.5, sigmoid : 0.8176
# x : 1.6, sigmoid : 0.8320
# x : 1.7, sigmoid : 0.8455
# x : 1.8, sigmoid : 0.8581
# x : 1.9, sigmoid : 0.8699
# x : 2.0, sigmoid : 0.8808
# x : 2.1, sigmoid : 0.8909
# x : 2.2, sigmoid : 0.9002
# x : 2.3, sigmoid : 0.9089
# x : 2.4, sigmoid : 0.9168
# x : 2.5, sigmoid : 0.9241
# x : 2.6, sigmoid : 0.9309
# x : 2.7, sigmoid : 0.9370
# x : 2.8, sigmoid : 0.9427
# x : 2.9, sigmoid : 0.9478

# %%
x = np.arange(-5, 5, 0.1)
y = sigmoid(x)
plt.plot(x,y)
plt.ylim(-0.1, 1.1)
# Out:
# (-0.1, 1.1)

# %% [markdown]
# ### 3.2.5. 시그모이드 함수와 계단 함수 비교

# %% [markdown]
# 차이점
#  - 연속성
#  - 매끄러움의 차이(미분가능성)
#  - 치역의 차이 : discrete vs continuous
#
# 공통점
#  - 작을 때 0, 클 때 1
#  - 함숫값이 0과 1 사이의 값을 넘어서지 않는다.

# %% [markdown]
# ### 3.2.6. 비선형 함수

# %% [markdown]
#  - 이 책에서는 선형함수를 $y=ax+b$인 함수로 정의하고 있다.
# 즉 affine function 또한 선형함수로 취급하고 있다.
#  - 선형함수를 합성하더라도 여전히 선형함수이다.

# %% [markdown]
# ### 3.2.7. ReLU 함수

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def relu(x):
    return np.max(0,x)

# %%
print(relu(2))
print(relu(2.0))
print(relu(np.array([2,3])))
# Out:
# 2
# 2.0
# [2 3]

# %%
def relu(x):
    return np.maximum(0,x)

# %%
print(relu(2))
print(relu(2.0))
print(relu(np.array([2,3])))
# Out:
# 2
# 2.0
# [2 3]

# %% [markdown]
# ## 3.3. 다차원 배열의 계산

# %% [markdown]
# ### 3.3.1. 다차원 배열

# %% [markdown]
# ### 3.3.2. 행렬의 곱

# %% [markdown]
# ### 3.3.3. 신경망에서 행렬 곱

# %% [markdown]
# ## 3.4. 3층 신경망 구현하기

# %% [markdown]
# ### 3.4.1. 표기법 설명

# %% [markdown]
# ### 3.4.2. 각 층의 신호 전달 구현하기

# %% [markdown]
# ### 3.4.3. 구현 정리

# %% [markdown]
# ## 3.5. 출력충 설계하기

# %% [markdown]
# ### 3.5.1. 항등 함수와 소프트맥스 함수 구현하기

# %% [markdown]
# ### 3.5.2. 소프트맥스 함수 구현 시 주의점

# %% [markdown]
# ### 3.5.3. 소프트맥스 함수의 특징

# %% [markdown]
# ### 3.5.4. 출력층의 뉴런 수 정하기

# %% [markdown]
# ## 3.6. 손글씨 숫자 인식

# %% [markdown]
# ### 3.6.1. MNIST 데이터셋

# %% [markdown]
# ### 3.6.2. 신경망의 추론 처리

# %% [markdown]
# ### 3.6.3. 배치 처리

# %% [markdown]
# ## 3.7. 정리
