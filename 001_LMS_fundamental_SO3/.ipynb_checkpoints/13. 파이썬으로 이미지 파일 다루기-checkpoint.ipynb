# %% [markdown]
# ## 13.1. 들어가며

# %% [markdown]
# ## 13.2. 디지털 이미지

# %% [markdown]
# ## 13.3. Pillow 사용법

# %%
import numpy as np
from PIL import Image

data = np.zeros([32, 32, 3], dtype=np.uint8)
image = Image.fromarray(data, 'RGB')
image
# Out:
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F4390EE19A0>

# %%
data[:, :] = [255, 0, 0]
image = Image.fromarray(data, 'RGB')
image
# Out:
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F4390EE15E0>

# %%
data = np.array([[1,3,5],[100,200,200],[250,250,250]]).astype(np.uint8)
#image = Image.fromarray(data,'RGB')
#image

# %% [markdown]
# 1. 가로 세로 각 128 픽셀짜리 흰색 이미지를 만들어 화면에 표시해 봅시다.

# %%
data = np.zeros([32, 32, 3], dtype=np.uint8)
data[:,:] = [255, 255, 255]
image = Image.fromarray(data, 'RGB')
image.show()
# Out:
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F4390F702B0>

# %%
data = np.zeros([32, 32, 3], dtype=np.uint8)
data[:,:] = [0, 0, 0]
image = Image.fromarray(data, 'RGB')
image.show()
data[:,:] = [255, 0, 0]
image = Image.fromarray(data, 'RGB')
image.show()
data[:,:] = [0, 255, 0]
image = Image.fromarray(data, 'RGB')
image.show()
data[:,:] = [0, 0, 255]
image = Image.fromarray(data, 'RGB')
image.show()
data[:,:] = [255, 255, 0]
image = Image.fromarray(data, 'RGB')
image.show()
data[:,:] = [255, 0, 255]
image = Image.fromarray(data, 'RGB')
image.show()
data[:,:] = [0, 255, 255]
image = Image.fromarray(data, 'RGB')
image.show()
data[:,:] = [255, 255, 255]
image = Image.fromarray(data, 'RGB')
image.show()
# Out:
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F43B85376D0>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F4390FDDA30>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F439168AE50>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F4390FDDF70>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F4390ECC1F0>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F4390ECCB50>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F4390FDDFD0>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F4390ECC1F0>

# %% [markdown]
# 2. 연습용 이미지를 열어 width와 height를 출력하고, .save()를 이용하여 jpg 파일 포맷으로 저장해 봅시다.
# (참고) JPG 파일로 save시 오류가 발생한다면 여기를 참고해 주세요

# %%
img = Image.open('13/data/pillow_practice.png')
print(img.width)
print(img.height)
img2 = img.convert('RGB')
img2.save('13/result/pillow_practice2.jpg')
# Out:
# 620
# 465

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=620x465 at 0x7F4390EC7D30>

# %% [markdown]
# 3. .resize()를 이용하여 이미지 크기를 100X200으로 변경하여 저장해봅시다.

# %%
img3 = img.resize((100,200))
img3 = img3.convert('RGB')
img3.show()
img3.save('13/result/pillow_practice3.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=100x200 at 0x7F4390EEB370>

# %% [markdown]
# 4. .crop()을 이용하여 눈 부분만 잘라내어 저장해 봅시다.
# (힌트) 눈 부분의 box 좌표는 (300, 100, 600, 400)입니다.

# %%
img4 = img.crop((300, 100, 600, 400))
img4 = img4.convert('RGB')
img4.show()
img4.save('13/result/pillow_practice4.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F4390ECCF40>

# %% [markdown]
# ## 13.4. Pillow를 활용한 데이터 전처리

# %%
import os
import pickle
from PIL import Image

dir_path = os.getenv('HOME')+'/aiffel/python_image_proc/data/cifar-100-python'
train_file_path = os.path.join(dir_path, 'train')

with open(train_file_path, 'rb') as f:
    train = pickle.load(f, encoding='bytes')

print(type(train))
# print(train)   # 혹시 내용이 궁금하다면 주석을 풀고 실행해 보세요.
# Out:
# <class 'dict'>

# %%
train.keys()
# Out:
# dict_keys([b'filenames', b'batch_label', b'fine_labels', b'coarse_labels', b'data'])

# %%
print(type(train[b'filenames']))
print(len(train[b'filenames']))
print(train[b'filenames'][0:5])
# Out:
# <class 'list'>
# 50000
# [b'bos_taurus_s_000507.png', b'stegosaurus_s_000125.png', b'mcintosh_s_000643.png', b'altar_boy_s_001435.png', b'cichlid_s_000031.png']

# %%
print(type(train[b'data']))
print(len(train[b'data']))
print(train[b'data'][0:5])
# Out:
# <class 'numpy.ndarray'>
# 50000
# [[255 255 255 ...  10  59  79]
#  [255 253 253 ... 253 253 255]
#  [250 248 247 ... 194 207 228]
#  [124 131 135 ... 232 236 231]
#  [ 43  32  87 ...  60  29  37]]

# %%
print(type(train[b'batch_label']))
print(len(train[b'batch_label']))
print(train[b'batch_label'])
# Out:
# <class 'bytes'>
# 21
# b'training batch 1 of 1'

# %%
print(type(train[b'fine_labels']))
print(len(train[b'fine_labels']))
print(train[b'fine_labels'][0:5])
# Out:
# <class 'list'>
# 50000
# [19, 29, 0, 11, 1]

# %%
print(type(train[b'coarse_labels']))
print(len(train[b'coarse_labels']))
print(train[b'coarse_labels'][0:5])
# Out:
# <class 'list'>
# 50000
# [11, 15, 4, 14, 1]

# %%
train[b'data'][0].shape
# Out:
# (3072,)

# %%
image_data = train[b'data'][0].reshape([32, 32, 3], order='F')   # order를 주의하세요!!
image = Image.fromarray(image_data)    # Pillow를 사용하여 Numpy 배열을 Image객체로 만들어서
image    # 화면에 띄워 봅시다!!
# Out:
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F4390EC7250>

# %%
image_data = train[b'data'][0].reshape([32, 32, 3])   # order를 주의하세요!!
image = Image.fromarray(image_data)    # Pillow를 사용하여 Numpy 배열을 Image객체로 만들어서
image    # 화면에 띄워 봅시다!!
# Out:
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F4390EC7F10>

# %%
image_data = train[b'data'][0].reshape([32, 32, 3], order='F')   # order를 주의하세요!!
image = Image.fromarray(image_data)    # Pillow를 사용하여 Numpy 배열을 Image객체로 만들어서
image = image.resize((300,300))
image    # 화면에 띄워 봅시다!!
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F43B9591A30>

# %%
for i in range(10):
    image_data = train[b'data'][i].reshape([32, 32, 3], order='F')   # order를 주의하세요!!
    image = Image.fromarray(image_data)    # Pillow를 사용하여 Numpy 배열을 Image객체로 만들어서
    image = image.resize((300,300))
    image.show()    # 화면에 띄워 봅시다!!
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F4390FD3580>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F4390ECC6A0>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F4390ECC6A0>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F4390ECC670>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F4390ECC8E0>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F4390ECC670>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F4390ECC6A0>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F4390ECC670>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F4390ECC670>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F4390ECC6A0>

# %%
image_data = image_data.swapaxes(0, 1)
image = Image.fromarray(image_data)
image
# Out:
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F4390EC7730>

# %%
for i in range(10):
    image_data = train[b'data'][i].reshape([32, 32, 3], order='F')   # order를 주의하세요!!
    image_data = image_data.swapaxes(0, 1)
    image = Image.fromarray(image_data)    # Pillow를 사용하여 Numpy 배열을 Image객체로 만들어서
    image = image.resize((300,300))
    image.show()    # 화면에 띄워 봅시다!!
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F4390EEB310>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F4390EEB310>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F4390EEBA30>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F4390EEB4F0>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F43B85234C0>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F4390EEBA30>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F4390EEB4F0>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F4390EEBA30>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F4390EEBA30>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F4390EEBA30>

# %%
import os
import pickle
from PIL import Image
import numpy
from tqdm import tqdm

dir_path = os.getenv('HOME')+'/aiffel/python_image_proc/data/cifar-100-python'
train_file_path = os.path.join(dir_path, 'train')

# image를 저장할 cifar-100-python의 하위 디렉토리(images)를 생성합니다. 
images_dir_path = os.getenv('HOME')+'/aiffel/python_image_proc/cifar-images'
if not os.path.exists(images_dir_path):
    os.mkdir(images_dir_path)  # images 디렉토리 생성

# 32X32의 이미지 파일 50000개를 생성합니다. 
with open(train_file_path, 'rb') as f:
    train = pickle.load(f, encoding='bytes')
    for i in tqdm(range(len(train[b'filenames']))):
        # [[YOUR CODE]]
# Out:
#   File "/tmp/ipykernel_31/3172094703.py", line 19
#     # [[YOUR CODE]]
#                    ^
# IndentationError: expected an indented block

# %% [markdown]
# ## 13.5. OpenCV (1) 안녕, OpenCV

# %%
import os
import cv2 as cv
import numpy as np
from  matplotlib import pyplot as plt
# %matplotlib inline

img_path = os.getenv('HOME')+'/aiffel/python_image_proc/data/cv_practice.png'
img = cv.imread(img_path)

# Convert BGR to HSV
hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)

# define range of blue color in HSV
lower_blue = np.array([100,100,100])
upper_blue = np.array([130,255,255])

# Threshold the HSV image to get only blue colors
mask = cv.inRange(hsv, lower_blue, upper_blue)

# Bitwise-AND mask and original image
res = cv.bitwise_and(img, img, mask=mask)

plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.show()
plt.imshow(cv.cvtColor(mask, cv.COLOR_BGR2RGB))
plt.show()
plt.imshow(cv.cvtColor(res, cv.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ## 13.6. OpenCV (2) 톺아보기

# %%
import os
import cv2 as cv
import numpy as np
from  matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv.imread('13/data/cv_practice.png')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1280, 1920, 3)

# %% [markdown]
# `imread` : Loads an image from a file.
#
# > The function imread loads an image from the specified file and returns it. If the image cannot be read (because of missing file, improper permissions, unsupported or invalid format), the function returns an empty matrix ( Mat::data==NULL ).

# %%
hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)

# %%
type(hsv)
# Out:
# numpy.ndarray

# %%
hsv.shape
# Out:
# (1280, 1920, 3)

# %% [markdown]
# HSV 색 공간 또는 HSV 모델은 색을 표현하는 하나의 방법이자, 그 방법에 따라 색을 배치하는 방식이다. 색상(Hue), 채도(Saturation), 명도(Value)의 좌표를 써서 특정한 색을 지정한다. 비슷한 것으로 HSL(Lightness), HSI(Intensity) 등이 있다.

# %% [markdown]
# `cvtColor` : Converts an image from one color space to another.

# %%
# define range of blue color in HSV
lower_blue = np.array([100,100,100])
upper_blue = np.array([130,255,255])

# %%
# Threshold the HSV image to get only blue colors
mask = cv.inRange(hsv, lower_blue, upper_blue)

# %%
type(mask)
# Out:
# numpy.ndarray

# %%
mask.shape
# Out:
# (1280, 1920)

# %% [markdown]
#  - 색상(Hue) : 100 ~ 130
#  - 채도(Saturation) : 100 ~ 255
#  - 명도(Value) : 100 ~ 255

# %%
res = cv.bitwise_and(img, img, mask=mask)

# %%
type(res)
# Out:
# numpy.ndarray

# %%
res.shape
# Out:
# (1280, 1920, 3)

# %% [markdown]
# `cv.bitwise_and` : computes bitwise conjunction of the two arrays (dst = src1 & src2) Calculates the per-element bit-wise conjunction of two arrays or an array and a scalar.

# %%
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.show()
plt.imshow(cv.cvtColor(mask, cv.COLOR_BGR2RGB))
plt.show()
plt.imshow(cv.cvtColor(res, cv.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ## 13.7. 실습 : 비슷한 이미지 찾아내기

# %%
import os
import pickle
import cv2
import numpy as np
from matplotlib import pyplot as plt
from tqdm import tqdm
from PIL import Image

# 전처리 시 생성했던 디렉토리 구조
dir_path = os.getenv('HOME')+'/aiffel/python_image_proc/'
train_file_path = os.path.join(dir_path, 'train')
images_dir_path = os.path.join(dir_path, 'cifar-images')
