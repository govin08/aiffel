# %% [markdown]
# - https://numpy.org/doc/stable/reference/generated/numpy.log1p.html
#
# - https://numpy.org/doc/stable/reference/generated/numpy.expm1.html

# %% [markdown]
#  - `np.log1p` : $f(x) = \log(1+x)$
#  - `np.expm1` : $f(x) = e^x-1$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
print(np.log1p(0))
print(np.expm1(0))
# Out:
# 0.0
# 0.0

# %%
x = np.linspace(-3,3,601)
y1 = np.log1p(x)
y2 = np.expm1(x)
plt.xlim(-3, 3)
plt.ylim(-3, 3)
plt.figsize=(5, 5)
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,x, color = 'k')
plt.axhline(0, color = 'k')
plt.axvline(0, color = 'k')
# Out:
# /tmp/ipykernel_48/943165406.py:2: RuntimeWarning: divide by zero encountered in log1p
#   y1 = np.log1p(x)
# /tmp/ipykernel_48/943165406.py:2: RuntimeWarning: invalid value encountered in log1p
#   y1 = np.log1p(x)
